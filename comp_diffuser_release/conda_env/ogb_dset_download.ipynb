# %% [markdown]
# ### Download OGBench Datasets

# %%
"""
Please install the CompDiffuser customized OGBench github repo first.

You can use this file to download offical OGBench datasets, curated by 
https://seohong.me/projects/ogbench/

Check this file in OGBench folder 'ogbench/utils.py' to modify the default download path.
The default path is < DEFAULT_DATASET_DIR = '~/.ogbench/data' >

This file is based on the code in the Official OGBench github repo.
"""

import ogbench, os

## 'egl' needs a GPU
os.environ['PYOPENGL_PLATFORM'] = 'egl'
os.environ['MUJOCO_GL'] = 'egl'


print("MUJOCO_GL =", os.environ.get("MUJOCO_GL"))
print("PYOPENGL_PLATFORM =", os.environ.get("PYOPENGL_PLATFORM"))
print("DISPLAY =", os.environ.get("DISPLAY"))

## which dataset to download
dataset_name = 'antmaze-giant-stitch-v0'
# dataset_name = 'humanoidmaze-medium-stitch-v0'
# dataset_name = 'humanoidmaze-large-stitch-v0'
# dataset_name = 'antsoccer-arena-stitch-v0'
# dataset_name = 'antsoccer-medium-stitch-v0'

env, train_dataset, val_dataset = ogbench.make_env_and_datasets(dataset_name)

# Train your offline goal-conditioned RL agent on the dataset.
# ...

# Evaluate the agent.
# for task_id in [1, 2, 3, 4, 5]:
for task_id in [1,]:
    # Reset the environment and set the evaluation task.
    ob, info = env.reset(
        options=dict(
            task_id=task_id,  # Set the evaluation task. Each environment provides five
                              # evaluation goals, and `task_id` must be in [1, 5].
            render_goal=True,  # Set to `True` to get a rendered goal image (optional).
        )
    )

    goal = info['goal']  # Get the goal observation to pass to the agent.
    goal_rendered = info['goal_rendered']  # Get the rendered goal image (optional).

    done = False
    imgs = []
    # while not done:
    for _ in range(10):
        action = env.action_space.sample()  # Replace this with your agent's action.
        ob, reward, terminated, truncated, info = env.step(action)  # Gymnasium-style step.
        # If the agent reaches the goal, `terminated` will be `True`. If the episode length
        # exceeds the maximum length without reaching the goal, `truncated` will be `True`.
        # `reward` is 1 if the agent reaches the goal and 0 otherwise.
        done = terminated or truncated
        frame = env.render()  # Render the current frame (optional).
        imgs.append(frame)

    success = info['success']  # Whether the agent reached the goal (0 or 1).
                               # `terminated` also indicates this.
# del env
# Out:
# MUJOCO_GL = egl
# PYOPENGL_PLATFORM = egl
# DISPLAY = None
# [OGBench Repo] Call: make_env_and_datasets(), make gymna env
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 31
#      25 dataset_name = 'antmaze-giant-stitch-v0'
#      26 # dataset_name = 'humanoidmaze-medium-stitch-v0'
#      27 # dataset_name = 'humanoidmaze-large-stitch-v0'
#      28 # dataset_name = 'antsoccer-arena-stitch-v0'
#      29 # dataset_name = 'antsoccer-medium-stitch-v0'
# ---> 31 env, train_dataset, val_dataset = ogbench.make_env_and_datasets(dataset_name)
#      33 # Train your offline goal-conditioned RL agent on the dataset.
#      34 # ...
#      35
#      36 # Evaluate the agent.
#      37 # for task_id in [1, 2, 3, 4, 5]:
#      38 for task_id in [1,]:
#      39     # Reset the environment and set the evaluation task.
#
# File /home/projects/crml-prj10844/ogbench_cpdfu_release/ogbench/utils.py:150, in make_env_and_datasets(dataset_name, dataset_dir, compact_dataset, env_only, **env_kwargs)
#     148 env_name = '-'.join(splits[:-2] + splits[-1:])  # Remove the dataset type.
#     149 print('[OGBench Repo] Call: make_env_and_datasets(), make gymna env')
# --> 150 env = gymnasium.make(env_name, **env_kwargs)
#     152 env.name = dataset_name
#     154 if env_only:
#
# File /home/projects/crml-prj10844/src/gymnasium/gymnasium/envs/registration.py:756, in make(id, max_episode_steps, autoreset, apply_api_compatibility, disable_env_checker, **kwargs)
#     753     env_creator = env_spec.entry_point
#     754 else:
#     755     # Assume it's a string
# --> 756     env_creator = load_env_creator(env_spec.entry_point)
#     758 # Determine if to use the rendering
#     759 render_modes: list[str] | None = None
#
# File /home/projects/crml-prj10844/src/gymnasium/gymnasium/envs/registration.py:545, in load_env_creator(name)
#     536 """Loads an environment with name of style ``"(import path):(environment name)"`` and returns the environment creation function, normally the environment class type.
#     537
#     538 Args:
#    (...)
#     542     The environment constructor for the given environment name.
#     543 """
#     544 mod_name, attr_name = name.split(":")
# --> 545 mod = importlib.import_module(mod_name)
#     546 fn = getattr(mod, attr_name)
#     547 return fn
#
# File /home/projects/crml-prj10844/miniforge3/envs/compdfu_ogb_release/lib/python3.9/importlib/__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:850, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File /home/projects/crml-prj10844/ogbench_cpdfu_release/ogbench/locomaze/maze.py:7
#       4 import numpy as np
#       5 from gymnasium.spaces import Box
# ----> 7 from ogbench.locomaze.ant import AntEnv
#       8 from ogbench.locomaze.humanoid import HumanoidEnv
#       9 from ogbench.locomaze.point import PointEnv
#
# File /home/projects/crml-prj10844/ogbench_cpdfu_release/ogbench/locomaze/ant.py:5
#       3 import numpy as np
#       4 from gymnasium import utils
# ----> 5 from gymnasium.envs.mujoco import MujocoEnv
#       6 from gymnasium.spaces import Box
#       9 class AntEnv(MujocoEnv, utils.EzPickle):
#
# File /home/projects/crml-prj10844/src/gymnasium/gymnasium/envs/mujoco/__init__.py:1
# ----> 1 from gymnasium.envs.mujoco.mujoco_env import MujocoEnv, MuJocoPyEnv  # isort:skip
#       3 # ^^^^^ so that user gets the correct error
#       4 # message if mujoco is not installed correctly
#       5 from gymnasium.envs.mujoco.ant import AntEnv
#
# File /home/projects/crml-prj10844/src/gymnasium/gymnasium/envs/mujoco/mujoco_env.py:20
#      17     MUJOCO_PY_IMPORT_ERROR = None
#      19 try:
# ---> 20     import mujoco
#      21 except ImportError as e:
#      22     MUJOCO_IMPORT_ERROR = e
#
# File /home/projects/crml-prj10844/miniforge3/envs/compdfu_ogb_release/lib/python3.9/site-packages/mujoco/__init__.py:57
#      55 from mujoco._specs import *
#      56 from mujoco._structs import *
# ---> 57 from mujoco.gl_context import *
#      58 from mujoco.renderer import Renderer
#      60 HEADERS_DIR = os.path.join(os.path.dirname(__file__), 'include/mujoco')
#
# File /home/projects/crml-prj10844/miniforge3/envs/compdfu_ogb_release/lib/python3.9/site-packages/mujoco/gl_context.py:41
#      39   GLContext = _GLContext
#      40 elif _SYSTEM == 'Linux' and _MUJOCO_GL == 'egl':
# ---> 41   from mujoco.egl import GLContext as _GLContext
#      42   GLContext = _GLContext
#      43 elif _SYSTEM == 'Darwin':
#
# File /home/projects/crml-prj10844/miniforge3/envs/compdfu_ogb_release/lib/python3.9/site-packages/mujoco/egl/__init__.py:31
#      25 elif PYOPENGL_PLATFORM.lower() != 'egl':
#      26   raise ImportError(
#      27       'Cannot use EGL rendering platform. '
#      28       'The PYOPENGL_PLATFORM environment variable is set to {!r} '
#      29       '(should be either unset or \'egl\').')
# ---> 31 from mujoco.egl import egl_ext as EGL
#      32 from OpenGL import error
#      35 def create_initialized_egl_device_display():
#
# File /home/projects/crml-prj10844/miniforge3/envs/compdfu_ogb_release/lib/python3.9/site-packages/mujoco/egl/egl_ext.py:27
#      24   pass
#      26 # pylint: disable=g-import-not-at-top
# ---> 27 from OpenGL import EGL
#      28 from OpenGL import error
#      30 # From the EGL_EXT_device_enumeration extension.
#
# File /home/projects/crml-prj10844/miniforge3/envs/compdfu_ogb_release/lib/python3.9/site-packages/OpenGL/EGL/__init__.py:2
#       1 """OpenGL.EGL the portable interface to GL environments"""
# ----> 2 from OpenGL.raw.EGL._types import *
#       3 from OpenGL.raw.EGL._errors import EGLError
#       4 from OpenGL.EGL.VERSION.EGL_1_0 import *
#
# File /home/projects/crml-prj10844/miniforge3/envs/compdfu_ogb_release/lib/python3.9/site-packages/OpenGL/raw/EGL/_types.py:77
#      73 NativeWindowType = EGLNativeWindowType
#      75 # Callback types, this is a hack to avoid making the
#      76 # khr module depend on the platform or needing to change generator for now...
# ---> 77 CALLBACK_TYPE = _p.PLATFORM.functionTypeFor( _p.PLATFORM.EGL )
#      78 EGLSetBlobFuncANDROID = CALLBACK_TYPE( ctypes.c_voidp, EGLsizeiANDROID, ctypes.c_voidp, EGLsizeiANDROID )
#      79 EGLGetBlobFuncANDROID = CALLBACK_TYPE( ctypes.c_voidp, EGLsizeiANDROID, ctypes.c_voidp, EGLsizeiANDROID )
#
# AttributeError: 'OSMesaPlatform' object has no attribute 'EGL'

# %% [markdown]
# #### render

# %%
import mediapy as mpy
import numpy as np
# mpy.show_images(imgs)
# mpy.show_video(imgs)
print( f'{imgs[0].shape=}' )
imgs[0].min()
mpy.show_image(imgs[0])
task_id = 2
ob, info = env.reset(options=dict( task_id=task_id, render_goal=True ,) , )
img = env.render()
# env.render_mode
# mpy.show_image(env.render())
# mpy.show_image( info['goal_rendered'] )
# env.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 import numpy as np
#       3 # mpy.show_images(imgs)
#       4 # mpy.show_video(imgs)
# ----> 5 print( f'{imgs[0].shape=}' )
#       6 imgs[0].min()
#       7 mpy.show_image(imgs[0])
#
# NameError: name 'imgs' is not defined

# %%
import os
dataset_path = '~/.ogbench/data/antmaze-giant-stitch-v0.npz'
dataset_path_2 = os.path.expanduser(dataset_path)
print(f'{dataset_path=}\n{dataset_path_2=}')
print( os.path.exists(dataset_path) )
print( os.path.exists(dataset_path_2) )
# Out:
# dataset_path='~/.ogbench/data/antmaze-giant-stitch-v0.npz'
# dataset_path_2='/nethome/yluo470/.ogbench/data/antmaze-giant-stitch-v0.npz'
# False
# True

# %%
os.path.expanduser(dataset_path_2) == dataset_path_2
# Out:
# True
